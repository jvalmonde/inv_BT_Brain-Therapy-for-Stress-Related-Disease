# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import ast

# %%
ribs = pd.read_csv("/mnt/shared_drive/data/brain_therapy/SMA03/SMA-3_Test_Data_Britta.csv")

# %%
ribs
# Out:
#       blobtype_name sensorblob_description  \
# 0         RSP Level                    NaN
# 1         ECG Level                    NaN
# 2         EDA Level                    NaN
# 3  Skin Temperature                   SKT2
# 4  Skin Temperature                   SKT1
# 5         PPG Level                    NaN
#
#                                   sensorblob_payload
# 0  [0.658599853515625,0.65863037109375,0.65864562...
# 1  [0.4755096435546875,0.476043701171875,0.480239...
# 2  [1.7279052734375,1.7279052734375,1.72882080078...
# 3  [-9.5306396484375,-9.5306396484375,-9.53094482...
# 4  [-4.47662353515625,-4.47784423828125,-4.477539...
# 5  [0.49609375,0.49609375,0.496124267578125,0.496...

# %%
ribs["sensor"] = ["RSP", "ECG", "EDA", "SKT1", "SKT2","PPG"]
Fs = 500 # sampling rate

# %%
data1 = ast.literal_eval(ribs.iloc[5]["sensorblob_payload"])

# %% [markdown]
# ## Whole Signal Plot

# %%
fig, axes = plt.subplots(6,1, figsize=(10,18), dpi = 150)
ax = axes.flatten()
for i in range(6):

    data = ast.literal_eval(ribs.iloc[i]["sensorblob_payload"])
    time_ = np.arange(0,len(data)/(Fs),1/Fs)
    ax[i].plot(time_/60, data, color = 'blue', lw=0.8)
    ax[i].set_xlabel("time, minutes")
    ax[i].set_title("Sensor = {}, Sampling Rate = {} Hz".format(ribs.iloc[i]["sensor"],Fs))
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Zoomed in Signal Plots

# %%
fig, axes = plt.subplots(6,1, figsize=(10,18), dpi = 150)
ax = axes.flatten()
for i in range(6):
    
    data = ast.literal_eval(ribs.iloc[i]["sensorblob_payload"])
    time_ = np.arange(0,len(data)/(Fs),1/Fs)
    
    data2 = data[Fs*60*1:Fs*60*1+Fs*10]
    time_2 = time_[Fs*60*1:Fs*60*1+Fs*10]
    ax[i].plot(time_2, data2, color = 'blue', lw=0.8)
    ax[i].set_title("Sensor = {}, Sampling Rate = {} Hz".format(ribs.iloc[i]["sensor"],Fs))
    ax[i].set_xlabel("time, seconds")
plt.tight_layout()
plt.show()
