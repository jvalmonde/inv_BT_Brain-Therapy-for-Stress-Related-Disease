# %%
BT_FA  = read.csv("/mnt/bkt_prd_dsv_brain_therapy_raw/Features/Working_Memory/features_for_anova_WM_dropped.csv")

# %%
remove_cols<-c("X","index","Participant","Type","type_order","context","context_order","Type_index","Context_Index")
column_names = colnames(BT_FA)
column_names <- column_names[! column_names %in% remove_cols]

# %%
column_names
# Out:
#  [1] "ecg_heart_rate_mean"   "ecg_hrv_std_mean"      "skin_temperature_mean"
#  [4] "eda_mean_mean"         "eda_no_of_peaks_mean"  "eda_lf_mean"
#  [7] "eda_hf_mean"           "eda_lf_hf_ratio_mean"  "ecg_heart_rate_sem"
# [10] "ecg_hrv_std_sem"       "skin_temperature_sem"  "eda_mean_sem"
# [13] "eda_no_of_peaks_sem"   "eda_lf_sem"            "eda_hf_sem"
# [16] "eda_lf_hf_ratio_sem"

# %% [markdown]
# ### ANOVA : NO INTERACTIONS BETWEEN FACTORS

# %%
for (column_name in column_names){
    formula <- formula(paste(column_name, " ~ Type_index+Context_Index "))
    result <- aov(formula, data = BT_FA)
        
    writeLines("\n\n\n")
    writeLines("----------------------------------------------------------------------------------")
    writeLines(paste("\t\t\t\t",column_name))
    writeLines("----------------------------------------------------------------------------------")
    print(summary(result))
    writeLines("----------------------------------------------------------------------------------")
    
}
# Out:
# ----------------------------------------------------------------------------------
# 				 ecg_heart_rate_mean
# ----------------------------------------------------------------------------------
#                Df Sum Sq Mean Sq F value Pr(>F)
# Type_index      1      7    6.60   0.062  0.803
# Context_Index   1     10   10.39   0.098  0.755
# Residuals     149  15801  106.05
# ----------------------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------------------
# 				 ecg_hrv_std_mean
# ----------------------------------------------------------------------------------
#                Df Sum Sq Mean Sq F value Pr(>F)
# Type_index      1   2354    2354   1.389 0.2405
# Context_Index   1   4983    4983   2.940 0.0885 .
# Residuals     149 252542    1695
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# ----------------------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------------------
# 				 skin_temperature_mean
# ----------------------------------------------------------------------------------
#                Df Sum Sq Mean Sq F value Pr(>F)
# Type_index      1    6.1   6.135   0.346  0.557
# Context_Index   1    0.0   0.032   0.002  0.966
# Residuals     149 2641.9  17.731
# ----------------------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------------------
# 				 eda_mean_mean
# ----------------------------------------------------------------------------------
#                Df Sum Sq Mean Sq F value Pr(>F)
# Type_index      1     55   54.63   2.425  0.122
# Context_Index   1      0    0.06   0.003  0.958
# Residuals     149   3357   22.53
# ----------------------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------------------
# 				 eda_no_of_peaks_mean
# ----------------------------------------------------------------------------------
#                Df Sum Sq Mean Sq F value Pr(>F)
# Type_index      1   94.2   94.21   5.670 0.0185 *
# Context_Index   1    0.7    0.70   0.042 0.8381
# Residuals     149 2475.8   16.62
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# ----------------------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------------------
# 				 eda_lf_mean
# ----------------------------------------------------------------------------------
#                Df  Sum Sq   Mean Sq F value Pr(>F)
# Type_index      1 0.00292 0.0029188   6.485 0.0119 *
# Context_Index   1 0.00010 0.0000958   0.213 0.6453
# Residuals     149 0.06706 0.0004501
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# ----------------------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------------------
# 				 eda_hf_mean
# ----------------------------------------------------------------------------------
#                Df   Sum Sq   Mean Sq F value Pr(>F)
# Type_index      1 0.000274 2.737e-04   4.375 0.0382 *
# Context_Index   1 0.000007 7.130e-06   0.114 0.7361
# Residuals     149 0.009322 6.256e-05
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# ----------------------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------------------
# 				 eda_lf_hf_ratio_mean
# ----------------------------------------------------------------------------------
#                Df Sum Sq Mean Sq F value Pr(>F)
# Type_index      1    3.9   3.896   3.708 0.0561 .
# Context_Index   1    0.4   0.403   0.384 0.5366
# Residuals     149  156.6   1.051
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# ----------------------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------------------
# 				 ecg_heart_rate_sem
# ----------------------------------------------------------------------------------
#                Df Sum Sq Mean Sq F value Pr(>F)
# Type_index      1  0.192 0.19156   1.957  0.164
# Context_Index   1  0.117 0.11700   1.196  0.276
# Residuals     149 14.582 0.09786
# ----------------------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------------------
# 				 ecg_hrv_std_sem
# ----------------------------------------------------------------------------------
#                Df Sum Sq Mean Sq F value Pr(>F)
# Type_index      1    400   399.9   0.857 0.3561
# Context_Index   1   2111  2111.2   4.523 0.0351 *
# Residuals     149  69549   466.8
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# ----------------------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------------------
# 				 skin_temperature_sem
# ----------------------------------------------------------------------------------
#                Df  Sum Sq  Mean Sq F value Pr(>F)
# Type_index      1 0.00347 0.003468   3.602 0.0596 .
# Context_Index   1 0.00095 0.000954   0.990 0.3212
# Residuals     149 0.14345 0.000963
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# ----------------------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------------------
# 				 eda_mean_sem
# ----------------------------------------------------------------------------------
#                Df Sum Sq  Mean Sq F value Pr(>F)
# Type_index      1 0.0010 0.000973   0.162  0.688
# Context_Index   1 0.0004 0.000415   0.069  0.793
# Residuals     149 0.8939 0.006000
# ----------------------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------------------
# 				 eda_no_of_peaks_sem
# ----------------------------------------------------------------------------------
#                Df Sum Sq Mean Sq F value Pr(>F)
# Type_index      1  10.53  10.526   6.636  0.011 *
# Context_Index   1   0.39   0.386   0.243  0.623
# Residuals     149 236.36   1.586
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# ----------------------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------------------
# 				 eda_lf_sem
# ----------------------------------------------------------------------------------
#                Df   Sum Sq   Mean Sq F value Pr(>F)
# Type_index      1 0.000155 1.549e-04   3.663 0.0575 .
# Context_Index   1 0.000023 2.306e-05   0.545 0.4614
# Residuals     149 0.006302 4.229e-05
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# ----------------------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------------------
# 				 eda_hf_sem
# ----------------------------------------------------------------------------------
#                Df   Sum Sq   Mean Sq F value Pr(>F)
# Type_index      1 2.78e-05 2.783e-05   2.900 0.0906 .
# Context_Index   1 4.90e-06 4.863e-06   0.507 0.4777
# Residuals     149 1.43e-03 9.595e-06
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# ----------------------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------------------
# 				 eda_lf_hf_ratio_sem
# ----------------------------------------------------------------------------------
#                Df Sum Sq Mean Sq F value  Pr(>F)
# Type_index      1  1.066  1.0657   7.346 0.00751 **
# Context_Index   1  0.003  0.0028   0.019 0.88940
# Residuals     149 21.615  0.1451
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# ----------------------------------------------------------------------------------

# %% [markdown]
# ## ANOVA WITH INTERACTIONS

# %% [markdown]
# Full Interactions

# %%
for (column_name in column_names){
    formula <- formula(paste(column_name, " ~ Type_index + Context_Index + (Type_index * Context_Index)"))
    result <- aov(formula, data = BT_FA)
        
    writeLines("\n\n\n")
    writeLines("----------------------------------------------------------------------------------")
    writeLines(paste("\t\t\t\t",column_name))
    writeLines("----------------------------------------------------------------------------------")
    print(summary(result))
    writeLines("----------------------------------------------------------------------------------")
    
}
# Out:
# ----------------------------------------------------------------------------------
# 				 ecg_heart_rate_mean
# ----------------------------------------------------------------------------------
#                           Df Sum Sq Mean Sq F value Pr(>F)
# Type_index                 1      7    6.60   0.062  0.804
# Context_Index              1     10   10.39   0.097  0.755
# Type_index:Context_Index   1     20   20.16   0.189  0.664
# Residuals                148  15781  106.63
# ----------------------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------------------
# 				 ecg_hrv_std_mean
# ----------------------------------------------------------------------------------
#                           Df Sum Sq Mean Sq F value Pr(>F)
# Type_index                 1   2354    2354   1.380 0.2420
# Context_Index              1   4983    4983   2.921 0.0895 .
# Type_index:Context_Index   1     52      52   0.031 0.8615
# Residuals                148 252490    1706
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# ----------------------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------------------
# 				 skin_temperature_mean
# ----------------------------------------------------------------------------------
#                           Df Sum Sq Mean Sq F value Pr(>F)
# Type_index                 1    6.1   6.135   0.344  0.559
# Context_Index              1    0.0   0.032   0.002  0.966
# Type_index:Context_Index   1    0.2   0.219   0.012  0.912
# Residuals                148 2641.6  17.849
# ----------------------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------------------
# 				 eda_mean_mean
# ----------------------------------------------------------------------------------
#                           Df Sum Sq Mean Sq F value Pr(>F)
# Type_index                 1     55   54.63   2.409  0.123
# Context_Index              1      0    0.06   0.003  0.958
# Type_index:Context_Index   1      0    0.39   0.017  0.896
# Residuals                148   3356   22.68
# ----------------------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------------------
# 				 eda_no_of_peaks_mean
# ----------------------------------------------------------------------------------
#                           Df Sum Sq Mean Sq F value Pr(>F)
# Type_index                 1   94.2   94.21   5.633 0.0189 *
# Context_Index              1    0.7    0.70   0.042 0.8386
# Type_index:Context_Index   1    0.5    0.47   0.028 0.8664
# Residuals                148 2475.3   16.72
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# ----------------------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------------------
# 				 eda_lf_mean
# ----------------------------------------------------------------------------------
#                           Df  Sum Sq   Mean Sq F value Pr(>F)
# Type_index                 1 0.00292 0.0029188   6.442 0.0122 *
# Context_Index              1 0.00010 0.0000958   0.211 0.6464
# Type_index:Context_Index   1 0.00000 0.0000000   0.000 0.9953
# Residuals                148 0.06706 0.0004531
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# ----------------------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------------------
# 				 eda_hf_mean
# ----------------------------------------------------------------------------------
#                           Df   Sum Sq   Mean Sq F value Pr(>F)
# Type_index                 1 0.000274 2.737e-04   4.351 0.0387 *
# Context_Index              1 0.000007 7.130e-06   0.113 0.7368
# Type_index:Context_Index   1 0.000011 1.089e-05   0.173 0.6780
# Residuals                148 0.009311 6.291e-05
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# ----------------------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------------------
# 				 eda_lf_hf_ratio_mean
# ----------------------------------------------------------------------------------
#                           Df Sum Sq Mean Sq F value Pr(>F)
# Type_index                 1   3.90   3.896   3.704 0.0562 .
# Context_Index              1   0.40   0.403   0.383 0.5368
# Type_index:Context_Index   1   0.88   0.884   0.840 0.3608
# Residuals                148 155.69   1.052
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# ----------------------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------------------
# 				 ecg_heart_rate_sem
# ----------------------------------------------------------------------------------
#                           Df Sum Sq Mean Sq F value Pr(>F)
# Type_index                 1  0.192 0.19156   1.945  0.165
# Context_Index              1  0.117 0.11700   1.188  0.278
# Type_index:Context_Index   1  0.006 0.00586   0.059  0.808
# Residuals                148 14.576 0.09849
# ----------------------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------------------
# 				 ecg_hrv_std_sem
# ----------------------------------------------------------------------------------
#                           Df Sum Sq Mean Sq F value Pr(>F)
# Type_index                 1    400   399.9   0.854 0.3571
# Context_Index              1   2111  2111.2   4.506 0.0354 *
# Type_index:Context_Index   1    199   198.6   0.424 0.5161
# Residuals                148  69350   468.6
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# ----------------------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------------------
# 				 skin_temperature_sem
# ----------------------------------------------------------------------------------
#                           Df  Sum Sq  Mean Sq F value Pr(>F)
# Type_index                 1 0.00347 0.003468   3.582 0.0604 .
# Context_Index              1 0.00095 0.000954   0.985 0.3226
# Type_index:Context_Index   1 0.00015 0.000147   0.152 0.6972
# Residuals                148 0.14330 0.000968
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# ----------------------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------------------
# 				 eda_mean_sem
# ----------------------------------------------------------------------------------
#                           Df Sum Sq  Mean Sq F value Pr(>F)
# Type_index                 1 0.0010 0.000973   0.161  0.689
# Context_Index              1 0.0004 0.000415   0.069  0.793
# Type_index:Context_Index   1 0.0010 0.000990   0.164  0.686
# Residuals                148 0.8930 0.006033
# ----------------------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------------------
# 				 eda_no_of_peaks_sem
# ----------------------------------------------------------------------------------
#                           Df Sum Sq Mean Sq F value Pr(>F)
# Type_index                 1  10.53  10.526   6.594 0.0112 *
# Context_Index              1   0.39   0.386   0.242 0.6237
# Type_index:Context_Index   1   0.08   0.084   0.052 0.8193
# Residuals                148 236.27   1.596
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# ----------------------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------------------
# 				 eda_lf_sem
# ----------------------------------------------------------------------------------
#                           Df   Sum Sq   Mean Sq F value Pr(>F)
# Type_index                 1 0.000155 1.549e-04   3.638 0.0584 .
# Context_Index              1 0.000023 2.306e-05   0.542 0.4629
# Type_index:Context_Index   1 0.000000 1.000e-08   0.000 0.9909
# Residuals                148 0.006302 4.258e-05
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# ----------------------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------------------
# 				 eda_hf_sem
# ----------------------------------------------------------------------------------
#                           Df    Sum Sq   Mean Sq F value Pr(>F)
# Type_index                 1 0.0000278 2.783e-05   2.891 0.0912 .
# Context_Index              1 0.0000049 4.863e-06   0.505 0.4784
# Type_index:Context_Index   1 0.0000050 4.970e-06   0.516 0.4736
# Residuals                148 0.0014247 9.626e-06
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# ----------------------------------------------------------------------------------
#
#
#
#
# ----------------------------------------------------------------------------------
# 				 eda_lf_hf_ratio_sem
# ----------------------------------------------------------------------------------
#                           Df Sum Sq Mean Sq F value  Pr(>F)
# Type_index                 1  1.066  1.0657   7.307 0.00767 **
# Context_Index              1  0.003  0.0028   0.019 0.88969
# Type_index:Context_Index   1  0.032  0.0317   0.217 0.64184
# Residuals                148 21.583  0.1458
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# ----------------------------------------------------------------------------------

# %% [markdown]
# ### LINEAR MIXED MODEL

# %%
library(lme4)
library(lmerTest)
# Out:
# Loading required package: Matrix
#
# Attaching package: ‘lmerTest’
#
# The following object is masked from ‘package:lme4’:
#
#     lmer
#
# The following object is masked from ‘package:stats’:
#
#     step

# %%
for (column_name in column_names){
    formula <- formula(paste(column_name, "~Type_index + Context_Index + (1 | Participant)"))
    lm_model <- lmer(formula, data = BT_FA)
    
    writeLines("\n\n")
    writeLines("----------------------------------------------------------------------------------")
    writeLines(paste("\t\t\t\t",column_name))
    writeLines("----------------------------------------------------------------------------------")
    writeLines("\n")
    print(summary(lm_model)$coefficients)
}
# Out:
# ----------------------------------------------------------------------------------
# 				 ecg_heart_rate_mean
# ----------------------------------------------------------------------------------
#
#
#                 Estimate Std. Error        df   t value     Pr(>|t|)
# (Intercept)   75.1746903  2.3638464  18.77909 31.801851 8.559358e-18
# Type_index     0.4167332  0.4093881 131.00002  1.017942 3.105820e-01
# Context_Index  0.2338593  0.1830839 131.00002  1.277334 2.037437e-01
#
#
#
# ----------------------------------------------------------------------------------
# 				 ecg_hrv_std_mean
# ----------------------------------------------------------------------------------
#
#
#                Estimate Std. Error        df   t value     Pr(>|t|)
# (Intercept)   65.384446   8.185021  30.45568  7.988305 5.791631e-09
# Type_index    -7.870833   4.754878 131.00015 -1.655318 1.002539e-01
# Context_Index -5.121165   2.126446 131.00015 -2.408321 1.741819e-02
#
#
#
# ----------------------------------------------------------------------------------
# 				 skin_temperature_mean
# ----------------------------------------------------------------------------------
#
#
#                  Estimate Std. Error        df    t value     Pr(>|t|)
# (Intercept)   28.74024245 0.96424613  18.89808 29.8059195 2.372317e-17
# Type_index    -0.40181041 0.17888306 131.00000 -2.2462183 2.636444e-02
# Context_Index -0.01294564 0.07999894 131.00000 -0.1618227 8.716948e-01
#
#
#
# ----------------------------------------------------------------------------------
# 				 eda_mean_mean
# ----------------------------------------------------------------------------------
#
#
#                  Estimate Std. Error        df    t value     Pr(>|t|)
# (Intercept)    7.36394090 1.10170395  18.24435  6.6841377 2.670720e-06
# Type_index     1.19904339 0.10796526 131.00000 11.1058262 1.327113e-20
# Context_Index -0.01811278 0.04828353 131.00000 -0.3751337 7.081677e-01
#
#
#
# ----------------------------------------------------------------------------------
# 				 eda_no_of_peaks_mean
# ----------------------------------------------------------------------------------
#
#
#                  Estimate Std. Error        df    t value     Pr(>|t|)
# (Intercept)    8.98815789  0.7965578  32.85696 11.2837485 7.665386e-13
# Type_index    -1.57456140  0.4914611 131.00001 -3.2038372 1.703065e-03
# Context_Index  0.06052632  0.2197881 131.00001  0.2753849 7.834545e-01
#
#
#
# ----------------------------------------------------------------------------------
# 				 eda_lf_mean
# ----------------------------------------------------------------------------------
#
#
#                   Estimate   Std. Error        df    t value     Pr(>|t|)
# (Intercept)    0.006286323 0.0044252663  25.22674  1.4205526 1.676897e-01
# Type_index     0.008764102 0.0020978158 131.00000  4.1777271 5.341445e-05
# Context_Index -0.000709972 0.0009381717 131.00000 -0.7567612 4.505518e-01
#
#
#
# ----------------------------------------------------------------------------------
# 				 eda_hf_mean
# ----------------------------------------------------------------------------------
#
#
#                    Estimate   Std. Error        df    t value    Pr(>|t|)
# (Intercept)    0.0024627955 0.0016310393  26.31762  1.5099547 0.142969026
# Type_index     0.0026839640 0.0008168034 131.00002  3.2859362 0.001304483
# Context_Index -0.0001937317 0.0003652856 131.00002 -0.5303567 0.596762525
#
#
#
# ----------------------------------------------------------------------------------
# 				 eda_lf_hf_ratio_mean
# ----------------------------------------------------------------------------------
#
#
#                  Estimate Std. Error       df    t value     Pr(>|t|)
# (Intercept)    2.31742881 0.20539129  29.4772 11.2829947 3.222007e-12
# Type_index     0.32020673 0.11591444 131.0001  2.7624404 6.562536e-03
# Context_Index -0.04606088 0.05183851 131.0001 -0.8885456 3.758760e-01
#
#
#
# ----------------------------------------------------------------------------------
# 				 ecg_heart_rate_sem
# ----------------------------------------------------------------------------------
#
#
#                  Estimate Std. Error        df   t value     Pr(>|t|)
# (Intercept)    0.75752422 0.06228955  30.26029 12.161337 3.519020e-13
# Type_index    -0.07100128 0.03598493 131.00001 -1.973084 5.059121e-02
# Context_Index -0.02481477 0.01609295 131.00001 -1.541965 1.254942e-01
#
#
#
# ----------------------------------------------------------------------------------
# 				 ecg_hrv_std_sem
# ----------------------------------------------------------------------------------
#
#
#                Estimate Std. Error        df   t value     Pr(>|t|)
# (Intercept)   19.385003   4.159789  35.20714  4.660093 4.408778e-05
# Type_index    -3.244196   2.692590 131.00001 -1.204861 2.304292e-01
# Context_Index -3.333417   1.204163 131.00001 -2.768244 6.453238e-03
#
#
#
# ----------------------------------------------------------------------------------
# 				 skin_temperature_sem
# ----------------------------------------------------------------------------------
#
#
#                  Estimate  Std. Error        df  t value     Pr(>|t|)
# (Intercept)   0.022066524 0.005748691  42.91047 3.838530 0.0004018906
# Type_index    0.009552988 0.004161115 131.00000 2.295776 0.0232771700
# Context_Index 0.002240267 0.001860907 131.00000 1.203858 0.2308154471
#
#
#
# ----------------------------------------------------------------------------------
# 				 eda_mean_sem
# ----------------------------------------------------------------------------------
#
#
#                   Estimate  Std. Error        df    t value     Pr(>|t|)
# (Intercept)    0.088329905 0.014692659  37.89119  6.0118392 5.541925e-07
# Type_index     0.005060535 0.009951456 131.00001  0.5085220 6.119426e-01
# Context_Index -0.001478642 0.004450427 131.00001 -0.3322472 7.402336e-01
#
#
#
# ----------------------------------------------------------------------------------
# 				 eda_no_of_peaks_sem
# ----------------------------------------------------------------------------------
#
#
#                  Estimate Std. Error        df    t value     Pr(>|t|)
# (Intercept)    1.92222824 0.22717249  50.11872  8.4615363 3.182347e-11
# Type_index    -0.52631300 0.17626626 131.00000 -2.9858975 3.375285e-03
# Context_Index  0.04506917 0.07882867 131.00000  0.5717358 5.684807e-01
#
#
#
# ----------------------------------------------------------------------------------
# 				 eda_lf_sem
# ----------------------------------------------------------------------------------
#
#
#                    Estimate   Std. Error        df   t value   Pr(>|t|)
# (Intercept)    0.0026656541 0.0012685214  33.13373  2.101387 0.04329288
# Type_index     0.0020191728 0.0007874726 131.00000  2.564118 0.01147200
# Context_Index -0.0003484157 0.0003521685 131.00000 -0.989344 0.32431873
#
#
#
# ----------------------------------------------------------------------------------
# 				 eda_hf_sem
# ----------------------------------------------------------------------------------
#
#
#                    Estimate   Std. Error        df    t value   Pr(>|t|)
# (Intercept)    0.0011737602 0.0005917369  36.57887  1.9835845 0.05484645
# Type_index     0.0008557708 0.0003924214 131.00000  2.1807445 0.03098819
# Context_Index -0.0001599758 0.0001754962 131.00000 -0.9115627 0.36367334
#
#
#
# ----------------------------------------------------------------------------------
# 				 eda_lf_hf_ratio_sem
# ----------------------------------------------------------------------------------
#
#
#                 Estimate Std. Error        df   t value     Pr(>|t|)
# (Intercept)   0.34304918 0.07428435  33.14854 4.6180548 0.0000560966
# Type_index    0.16746249 0.04612919 131.00000 3.6302931 0.0004047789
# Context_Index 0.00384906 0.02062960 131.00000 0.1865795 0.8522789938
